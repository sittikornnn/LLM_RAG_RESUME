# %%
import os
from dotenv import load_dotenv
from pinecone import Pinecone

load_dotenv()

pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
index = pc.Index("production")

# %%
# Define the query
query = "skill"

# Search the dense index
results = index.search(
    namespace="resume-namespace",
    query={
        "top_k": 10,
        "inputs": {
            'text': query
        }
    }
)

# Print the results
for hit in results['result']['hits']:
        print(f"id: {hit['_id']:<5} | score: {round(hit['_score'], 2):<5} | text: {hit['fields']['text']:<50}")
# Out:
# id: doc1#chunk9 | score: 0.32  | text: ## SKILLS
# id: doc1#chunk21 | score: 0.2   | text: SKILL ASSESSMENT PROGRAM (PDSAS).
# id: doc1#chunk17 | score: 0.16  | text: ## EXPERIENCE
# id: doc1#chunk50 | score: 0.15  | text: <!-- image -->
#
# <!-- image -->
#
# 0616046040
#
# sittikorn720@gmail.com
#
# github
#
# linkedin
# id: doc1#chunk1 | score: 0.14  | text: <!-- image -->
#
# ## ABOUT ME
# id: doc1#chunk10 | score: 0.13  | text: - Programming Languages: Python, JavaScript, TypeScript, HTML, CSS, Shell Script
# id: doc1#chunk20 | score: 0.12  | text: - Collaborated  with  a  two-person  team  to  develop  a  PHARMACIST  DISPENSE  SKILL ASSESSMENT
# id: doc1#chunk30 | score: 0.12  | text: training to web application deployment.
# id: doc1#chunk43 | score: 0.11  | text: logistics, and marketing.
# id: doc1#chunk15 | score: 0.11  | text: Excel), Power BI, Ollama
